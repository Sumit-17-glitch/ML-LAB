# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Titanic.csv");
df.shape
# Out:
# (418, 12)

# %%
print(df.head());
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(df.duplicated().sum());
# Out:
# 0

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
print(df.isna().sum());
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
columns = df.columns
columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(df['PassengerId'].unique());
# Out:
# [ 892  893  894  895  896  897  898  899  900  901  902  903  904  905
#   906  907  908  909  910  911  912  913  914  915  916  917  918  919
#   920  921  922  923  924  925  926  927  928  929  930  931  932  933
#   934  935  936  937  938  939  940  941  942  943  944  945  946  947
#   948  949  950  951  952  953  954  955  956  957  958  959  960  961
#   962  963  964  965  966  967  968  969  970  971  972  973  974  975
#   976  977  978  979  980  981  982  983  984  985  986  987  988  989
#   990  991  992  993  994  995  996  997  998  999 1000 1001 1002 1003
#  1004 1005 1006 1007 1008 1009 1010 1011 1012 1013 1014 1015 1016 1017
#  1018 1019 1020 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031
#  1032 1033 1034 1035 1036 1037 1038 1039 1040 1041 1042 1043 1044 1045
#  1046 1047 1048 1049 1050 1051 1052 1053 1054 1055 1056 1057 1058 1059
#  1060 1061 1062 1063 1064 1065 1066 1067 1068 1069 1070 1071 1072 1073
# ...

# %%
df.isna().replace("0", inplace="true");
# Out:
# C:\Users\kumbh\AppData\Local\Temp\ipykernel_22436\2421684405.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df.isna().replace("0", inplace="true");
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.isna().replace("0", inplace="true")
#
# File c:\Users\kumbh\anaconda3\Lib\site-packages\pandas\core\generic.py:7945, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7934 if not (
#    7935     is_scalar(to_replace)
#    7936     or is_re_compilable(to_replace)
#    7937     or is_list_like(to_replace)
#    7938 ):
#    7939     raise TypeError(
#    7940         "Expecting 'to_replace' to be either a scalar, array-like, "
#    7941         "dict or None, got invalid type "
# ...
