# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_csv("C:\College work\ML-LAB\Titanic.csv");
titanic.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\kumbh\AppData\Local\Temp\ipykernel_11612\1180933184.py:6: SyntaxWarning: invalid escape sequence '\C'
# ...

# %%
print(titanic.head());
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(titanic.describe());
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
print(titanic.describe().transpose());
# Out:
#              count         mean         std     min       25%        50%  \
# PassengerId  418.0  1100.500000  120.810458  892.00  996.2500  1100.5000
# Survived     418.0     0.363636    0.481622    0.00    0.0000     0.0000
# Pclass       418.0     2.265550    0.841838    1.00    1.0000     3.0000
# Age          332.0    30.272590   14.181209    0.17   21.0000    27.0000
# SibSp        418.0     0.447368    0.896760    0.00    0.0000     0.0000
# Parch        418.0     0.392344    0.981429    0.00    0.0000     0.0000
# Fare         417.0    35.627188   55.907576    0.00    7.8958    14.4542
#
#                  75%        max
# PassengerId  1204.75  1309.0000
# Survived        1.00     1.0000
# Pclass          3.00     3.0000
# Age            39.00    76.0000
# SibSp           1.00     8.0000
# Parch           0.00     9.0000
# Fare           31.50   512.3292

# %%
print(titanic["Survived"].value_counts());
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(data=titanic, x="Survived");

# %%
print(titanic["Pclass"].value_counts());
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
sns.countplot(data=titanic, x = "Pclass");

# %%
survived_class = titanic[['Survived','Pclass']];
print(survived_class.head());
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       3
# 2         0       2
# 3         0       3
# 4         1       3

# %%
titanic.Sex.value_counts().plot(kind='pie');

# %%
print(titanic.isnull().sum());
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
sns.heatmap(titanic.isnull(), yticklabels=False, cbar=False);

# %%
sns.countplot(data=titanic, x = "Survived", palette='autumn', hue = "Pclass");

# %%
sns.countplot(data=titanic, x = "Survived", palette='viridis', hue = "Pclass");

# %%
titanic.Fare.plot(kind="hist", bins= 10, color="yellow");

# %%
sns.scatterplot(data=titanic, x = 'Age', y = 'Fare', hue = 'Pclass');

# %%
print(titanic.info());
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Age          332 non-null    float64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Ticket       418 non-null    object
#  7   Fare         417 non-null    float64
#  8   Cabin        91 non-null     object
#  9   Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 32.8+ KB
# None

# %%
print(titanic.info());
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   SibSp        418 non-null    int64
#  4   Parch        418 non-null    int64
# dtypes: int64(5)
# memory usage: 16.5 KB
# None

# %%
correlation = titanic.corr();
print(correlation);
# Out:
#              PassengerId  Survived    Pclass     SibSp     Parch
# PassengerId     1.000000 -0.023245 -0.026751  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000  0.001087  0.018721
# SibSp           0.003818  0.099943  0.001087  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721  0.306895  1.000000
